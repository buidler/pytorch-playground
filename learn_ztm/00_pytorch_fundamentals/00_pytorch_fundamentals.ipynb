# %% [markdown]
# ## 导入pytorch

# %%
import torch
from pyarrow.compute import scalar

torch.__version__
# Out:
# '2.9.0+cpu'

# %% [markdown]
# ## tensor介绍

# %% [markdown]
# ### 创建tensor

# %%
scalar = torch.tensor(7)
print(scalar)
# Out:
# tensor(7)

# %% [markdown]
# ### 查看tensor维度

# %%
scalar.ndim
# Out:
# 0

# %% [markdown]
# ### 从tnesor中取回数据到python

# %%
#只对单元素tensors有效
s = scalar.item()
print(s)
# Out:
# 7

# %% [markdown]
# ### 向量
#
# 向量是一个一维的tensor，类似于一维数组

# %%
vector = torch.tensor([7,8])
print(vector)
# Out:
# tensor([7, 8])

# %% [markdown]
# #### vector的维度（和数组类似）
#
# 外层有几个[，就有几个维度

# %%
vector.ndim
# Out:
# 1

# %% [markdown]
# #### 数据的形状

# %%
vector.shape
# Out:
# torch.Size([2])

# %% [markdown]
# ### 矩阵

# %%
MATRIX = torch.tensor([[7,8],[9,10]])
print(MATRIX)
# Out:
# tensor([[ 7,  8],
#         [ 9, 10]])

# %%
MATRIX.ndim
# Out:
# 2

# %%
MATRIX.shape
# Out:
# torch.Size([2, 2])

# %% [markdown]
# ### tensor

# %%
TENSOR = torch.tensor([[[6,7,8],[9,10,11],[12,13,14]]])
print(TENSOR)
# Out:
# tensor([[[ 6,  7,  8],
#          [ 9, 10, 11],
#          [12, 13, 14]]])

# %%
print(TENSOR.ndim)
# Out:
# 3

# %%
print(TENSOR.shape)
# Out:
# torch.Size([1, 3, 3])

# %% [markdown]
# >维度从外到内
#
# ![image.png](attachment:0c95b029-638d-4d39-815e-9cd2fb079cd5.png)

# %% [markdown]
# | 名字    | 是什么?                                      | 维度dimensions                     | 大写或小写(通常/例子) |
# |---------|---------------------------------------------|------------------------------------|------------------------|
# | scalar  | 单独的数字                                  | 0                                  | Lower（a）|
# | vector  | 有方向的量(e.g. 有方向的风速)，也可以包含很多数字 | 1                                  | Lower（y）|
# | matrix  | 2维数组                                     | 2                                  | Upper（Q）|
# | tensor  | n维度数组                                    | n=0时是scalar, n=1时是vector | Upper（X）|

# %% [markdown]
# ![image.png](attachment:dad9e2e4-e304-42a0-b5b6-312ea8820414.png)

# %% [markdown]
# #### 随机tansors

# %% [markdown]
# 机器学习通常使用的是tensor，但是不是手动创建，是随机创建
#
# >机器学习过程：从随机数字开始 → 查看数据 → 更新数字 → 查看数据 → 更新数字...

# %%
random_tensor = torch.randn(3,4)
# rand:均匀分布，randn：标准正态分布
print(random_tensor)
print(random_tensor.dtype)
# Out:
# tensor([[ 0.8204,  0.4272,  0.0900,  0.8500],
#         [ 0.2330,  0.5069,  2.3987, -1.1704],
#         [ 0.5471, -1.9595,  0.3864, -0.3798]])
# torch.float32

# %%
rand_tensor = torch.rand(3,4,5)
print(rand_tensor.shape)
print(rand_tensor.ndim)
# Out:
# torch.Size([3, 4, 5])
# 3
